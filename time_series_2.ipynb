# %% [markdown]
# #Using the Kinetics Tool Kit Library

# %%
#Importing and using the KTK Library
#Creating and analysing Time Series

import kineticstoolkit as ktk
import kineticstoolkit.lab as ktk
import numpy as np
import matplotlib.pyplot as plt


ts = ktk.TimeSeries() #Initiating an empty array (to store time)
ts.time = np.linspace(0,1,100) #Adding time data to the array
# ts.data["cosine"] = np.cos(ts.time)

#Exercise - The position of an object has been recorded in meters during one second at a sampling frequency of 100 Hz
#Create a TimeSeries that contains this data and its corresponding time, so that the plot given can be viewed

pos = np.array(
    [
        0.    , 0.0099, 0.0196, 0.0291, 0.0384, 0.0475, 0.0564, 0.0651,
        0.0736, 0.0819, 0.09  , 0.0979, 0.1056, 0.1131, 0.1204, 0.1275,
        0.1344, 0.1411, 0.1476, 0.1539, 0.16  , 0.1659, 0.1716, 0.1771,
        0.1824, 0.1875, 0.1924, 0.1971, 0.2016, 0.2059, 0.21  , 0.2139,
        0.2176, 0.2211, 0.2244, 0.2275, 0.2304, 0.2331, 0.2356, 0.2379,
        0.24  , 0.2419, 0.2436, 0.2451, 0.2464, 0.2475, 0.2484, 0.2491,
        0.2496, 0.2499, 0.25  , 0.2499, 0.2496, 0.2491, 0.2484, 0.2475,
        0.2464, 0.2451, 0.2436, 0.2419, 0.24  , 0.2379, 0.2356, 0.2331,
        0.2304, 0.2275, 0.2244, 0.2211, 0.2176, 0.2139, 0.21  , 0.2059,
        0.2016, 0.1971, 0.1924, 0.1875, 0.1824, 0.1771, 0.1716, 0.1659,
        0.16  , 0.1539, 0.1476, 0.1411, 0.1344, 0.1275, 0.1204, 0.1131,
        0.1056, 0.0979, 0.09  , 0.0819, 0.0736, 0.0651, 0.0564, 0.0475,
        0.0384, 0.0291, 0.0196, 0.0099
    ]
)

ts.data["Position"] = pos

#Adding events on the data
ts = ts.add_event(0.0,"Starting point")
ts = ts.add_event(0.3, "Increasing height")
ts = ts.add_event(0.5, "Reaching peak")
ts = ts.add_event(0.8,"Decreasing height")
ts = ts.add_event(1.0, "Hit the ground")

ts = ts.add_data_info("Height", "Unit", "Meters")

ts.plot()
